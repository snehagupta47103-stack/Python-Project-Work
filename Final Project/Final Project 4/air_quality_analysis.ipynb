# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('Air_Quality.csv')
df

# %%
df.info()

# %%
df.isnull().sum()

# %%
df.describe()

# %%
df.duplicated().sum()

# %%
df.replace(-200, np.nan, inplace=True)

# %%
plt.figure(figsize=(10,5))
plt.plot(df["CO(GT)"].head(200))
plt.title("CO(GT) Analysis")
plt.xlabel("Index")
plt.ylabel("CO(GT)")
plt.show()

# %%
df["NO2(GT)"].head(20).plot(kind="bar")
plt.title("NO2(GT) Analysis")
plt.xlabel("Index")
plt.ylabel("NO2(GT)")
plt.show()

# %%
plt.hist(df["T"].dropna(), bins=15)
plt.title("Temperature Distribution")
plt.xlabel("Temperature")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap="Blues")
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(7,5))
plt.scatter(df["T"].head(300), df["CO(GT)"].head(300))
plt.title("Temperature vs CO(GT)")
plt.xlabel("Temperature")
plt.ylabel("CO(GT)")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(y=df["NO2(GT)"])
plt.title("NO2(GT) Distribution")
plt.show()

# %%
# 🌍 Key Insights – Air Quality Analysis

## 🌫️ Overall Findings
- The dataset contains information about various air pollutants, including **CO(GT), NOx(GT), NO2(GT), Temperature (T), Relative Humidity (RH), 
  and Absolute Humidity (AH)**.
- Some columns contain missing or invalid values (represented by **-200**), which should be handled before performing detailed analysis.
- Exploratory Data Analysis (EDA) helps understand pollutant levels and environmental conditions over time.

## 🌬️ Carbon Monoxide (CO) Analysis
- CO(GT) values fluctuate across different observations, indicating variations in air pollution levels.
- The line plot helps identify trends and changes in carbon monoxide concentration.

## 🌡️ Temperature Analysis
- Temperature values vary throughout the dataset.
- The histogram shows how temperature is distributed and helps identify the most common temperature range.

## 💨 Nitrogen Dioxide (NO₂) Analysis
- NO₂(GT) values are spread across a wide range.
- The box plot highlights the distribution of NO₂ levels and identifies possible outliers.

## 💧 Humidity Analysis
- Relative Humidity (RH) and Absolute Humidity (AH) provide useful information about atmospheric conditions.
- Humidity can influence the concentration and behavior of air pollutants.

## 📊 Correlation Analysis
- The heatmap illustrates the relationships between numerical variables.
- Some pollutants show positive or negative correlations, indicating how changes in one variable may relate to another.

## 📈 Data Visualization Insights
- Line plots effectively display changes in pollutant levels over time.
- Histograms help understand the distribution of environmental variables.
- Box plots reveal the spread of data and potential outliers.
- Heatmaps make it easier to identify relationships between different air quality parameters.

## 📌 Statistical Insights
- Descriptive statistics provide information about the mean, minimum, maximum, and standard deviation of each numerical variable.
- Missing value analysis improves data quality before visualization and interpretation.

## 💡 Conclusion
This project provides a comprehensive overview of air quality and environmental conditions using Python. Data cleaning, statistical analysis, 
and visualizations help identify pollution trends, environmental patterns, and relationships among different air quality parameters. 
The project demonstrates the practical use of **Pandas**, **Matplotlib**, and **Seaborn** for real-world environmental data analysis.
