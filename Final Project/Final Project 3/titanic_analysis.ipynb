# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('Titanic.csv')
df.head()

# %%
print("------Dataset Information-----")
df.info()

print("="*50)

print("-----Descriptive Statistics-----")
print(df.describe())

print("="*50)

print("-----Missing Values-----")
print(df.isnull().sum())

# %%
print("------Duplicate Value-----")
df.duplicated().sum()

# %%
df["Pclass"].value_counts()

# %%
df["Sex"].value_counts()

# %%
df["Embarked"].value_counts()

# %%
df["Age"].describe()

# %%
df["Fare"].describe()

# %%
df["Pclass"].value_counts().plot(kind="bar")
plt.title("Passenger Class Distribution")
plt.xlabel("Passenger Class")
plt.ylabel("Number of Passengers")
plt.show()

# %%
df["Sex"].value_counts().plot(kind="pie",autopct="%1.1f%%")
plt.legend()
plt.title("Gender Distribution")
plt.show()

# %%
plt.hist(df["Age"].dropna(), bins=10)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Number of Passengers")
plt.show()

# %%
df["Embarked"].value_counts().plot(kind="bar")
plt.title("Embarked Distribution")
plt.xlabel("Embarked")
plt.ylabel("Number of Passengers")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(y=df["Fare"])
plt.title("Fare Distribution")
plt.ylabel("Fare")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="Blues")
plt.title("Correlation Heatmap")
plt.show()

# %%
df.groupby("Pclass")["Fare"].mean().plot(kind="bar")
plt.title("Average Fare by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Average Fare")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x="Pclass", y="Age", data=df)
plt.title("Passenger Age by Class")
plt.show()

# %%
# 📊 Key Insights – Titanic Passenger Analysis

## 🚢 Overall Findings
- The dataset contains detailed information about Titanic passengers, including passenger class, age, gender, fare, cabin, and embarkation port.
- Some columns, such as **Age**, **Cabin**, and **Embarked**, contain missing values that should be handled before performing analysis.
- Passenger Class (Pclass) helps categorize passengers into First, Second, and Third Class.
- The majority of passengers belong to a particular passenger class, indicating an unequal distribution among travel classes.

## 👥 Gender Analysis
- The dataset includes both male and female passengers.
- Gender distribution provides useful demographic information about the passengers on board.

## 🎂 Age Analysis
- Passenger ages vary across different age groups.
- Most passengers fall within the adult age range, while a smaller number are children and elderly passengers.
- Missing values in the Age column should be considered during analysis.

## 💰 Fare Analysis
- Ticket fares vary significantly depending on passenger class and ticket type.
- Higher passenger classes generally have higher ticket fares.
- The Fare distribution contains some high-value outliers, which can be observed in the box plot.

## 🚢 Embarked Analysis
- Passengers boarded the Titanic from different embarkation ports.
- One embarkation port has the highest number of passengers compared to the others.
- A few records have missing embarkation information.

## 📈 Data Visualization Insights
- Bar charts clearly show the distribution of passenger classes and embarkation ports.
- Pie charts effectively represent the gender distribution.
- Histograms help visualize the age distribution of passengers.
- Box plots identify fare variation and potential outliers.
- Heatmaps display the relationships among numerical variables in the dataset.

## 📌 Statistical Insights
- Descriptive statistics provide information about the average age, average fare, minimum values, maximum values, and data distribution.
- Correlation analysis helps understand relationships between numerical features such as Age, Fare, SibSp, and Parch.

## 💡 Conclusion
This analysis provides valuable insights into the demographic characteristics of Titanic passengers. Data cleaning, descriptive statistics, 
and visualizations help in understanding passenger distribution, ticket fare patterns, age distribution, and embarkation details. 
The project demonstrates how Python libraries such as Pandas, Matplotlib, and Seaborn can be used to explore and analyze real-world datasets 
effectively.
